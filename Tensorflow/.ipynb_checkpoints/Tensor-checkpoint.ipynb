# %%
import tensorflow as tf
import numpy as np

# %%
rank_0_tensor = tf.constant(4) # Can't be changed after set
print(rank_0_tensor)
# Out:
# tf.Tensor(4, shape=(), dtype=int32)

# %%
rank_1_tensor = tf.constant([1.4, 49.2, 10.3])
print(rank_1_tensor)
# Out:
# tf.Tensor([ 1.4 49.2 10.3], shape=(3,), dtype=float32)

# %%
rank_2_tensor = tf.constant([[2, 4, 5],[2, 4, 5]])
print(rank_2_tensor)
# Out:
# tf.Tensor(
# [[2 4 5]
#  [2 4 5]], shape=(2, 3), dtype=int32)

# %% [markdown]
# ![Screen Shot 2021-08-21 at 11.54.13 PM.png](attachment:26be8527-83d7-47f1-b699-4c88197d298c.png)

# %%
# Convert to numpy array
np.array(rank_0_tensor)
rank_1_tensor.numpy()
# Out:
# array([ 1.4, 49.2, 10.3], dtype=float32)

# %%
a = tf.constant([[1, 2],[3, 4]])
b = tf.ones([2,2], dtype=tf.int32)

# %%
tf.add(a, b)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2, 3],
#        [4, 5]], dtype=int32)>

# %%
tf.multiply(a, b)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
tf.matmul(a, b)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[3, 3],
#        [7, 7]], dtype=int32)>

# %%
print(a + b)
# Out:
# tf.Tensor(
# [[2 3]
#  [4 5]], shape=(2, 2), dtype=int32)

# %%
print(a * b)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
print(a @ b)
# Out:
# tf.Tensor(
# [[3 3]
#  [7 7]], shape=(2, 2), dtype=int32)

# %%
c = tf.constant([[3., 5., 1.], [7. , 9. , 0.]])

# Finds largest value
print(tf.reduce_max(c))

# Finds the index of the largest value
print(tf.argmax(c))

# compute the softmax
print(tf.nn.softmax(c))
# Out:
# tf.Tensor(9.0, shape=(), dtype=float32)
# tf.Tensor([1 1 0], shape=(3,), dtype=int64)
# tf.Tensor(
# [[1.1731042e-01 8.6681330e-01 1.5876239e-02]
#  [1.1918997e-01 8.8070136e-01 1.0868718e-04]], shape=(2, 3), dtype=float32)

# %% [markdown]
# ![Screen Shot 2021-08-21 at 11.45.11 PM.png](attachment:aadb69a9-1e87-4c44-adef-56810dfc5c05.png)

# %%
rank_4_tensor = tf.zeros([3, 2, 4, 5])

# %%
print("Type of every element:", rank_4_tensor.dtype)
print("Number of axes:", rank_4_tensor.ndim)
print("Shape of tensor:", rank_4_tensor.shape)
print("Elements along axis 0 of tensor:", rank_4_tensor.shape[0])
print("Elements along the last axis of tensor:", rank_4_tensor.shape[-1])
print("Total number of elements (3 * 2 * 4 * 5):", tf.size(rank_4_tensor).numpy())
# Out:
# Type of every element: <dtype: 'float32'>
# Number of axes: 4
# Shape of tensor: (3, 2, 4, 5)
# Elements along axis 0 of tensor: 3
# Elements along the last axis of tensor: 5
# Total number of elements (3 * 2 * 4 * 5): 120

# %% [markdown]
# ![Screen Shot 2021-08-21 at 11.51.55 PM.png](attachment:d9d04245-9c16-4f49-9358-9cb8a7e4a303.png)

# %% [markdown]
# ![Screen Shot 2021-08-21 at 11.53.38 PM.png](attachment:469f5fbe-c3b7-4872-a84a-7add375443d2.png)

# %%
rank_1_tensor = tf.constant([0, 1, 1, 3, 5, 2, 6, 20])
print(rank_1_tensor.numpy())
# Out:
# [ 0  1  1  3  5  2  6 20]

# %%
print("First:", rank_1_tensor[0].numpy())
print("second:", rank_1_tensor[1].numpy())
print("Last:", rank_1_tensor[-1].numpy())
# Out:
# First: 0
# second: 1
# Last: 20

# %%
print("Everything:", rank_1_tensor[:].numpy())
print("Before 4:", rank_1_tensor[:4].numpy())
print("From 4 to the end:", rank_1_tensor[4:].numpy())
print("From 2, before 7:", rank_1_tensor[2:7].numpy())
print("Every other item:", rank_1_tensor[::2].numpy())
print("Reversed:", rank_1_tensor[::-1].numpy())
# Out:
# Everything: [ 0  1  1  3  5  2  6 20]
# Before 4: [0 1 1 3]
# From 4 to the end: [ 5  2  6 20]
# From 2, before 7: [1 3 5 2 6]
# Every other item: [0 1 5 6]
# Reversed: [20  6  2  5  3  1  1  0]

# %% [markdown]
# ![Screen Shot 2021-08-22 at 12.01.13 AM.png](attachment:e3d806df-ea67-43fc-9df9-3da89a9b4176.png)

# %%
print(rank_2_tensor.numpy())
# Out:
# [[2 4 5]
#  [2 4 5]]

# %%
# Pull out an integer for each index 
print(rank_2_tensor[1, 1].numpy())
# Out:
# 4

# %%
# Get row and column tensors
print("Second row:", rank_2_tensor[1, :].numpy())
print("Second column:", rank_2_tensor[:, 1].numpy())
print("Last row:", rank_2_tensor[-1, :].numpy())
print("First item in last column:", rank_2_tensor[0, -1].numpy())
print("Skip the first row:")
print(rank_2_tensor[1:, :].numpy(), "\n")
# Out:
# Second row: [2 4 5]
# Second column: [4 4]
# Last row: [2 4 5]
# First item in last column: 5
# Skip the first row:
# [[2 4 5]]
